# %%
import os
import matplotlib.pyplot as plt

filename = "../Files/HLVK_Samples_Flow.hdf"
size_bytes = os.path.getsize(filename)
size_mb = size_bytes / (1024**2)

print(f"Size: {size_bytes} bytes ({size_mb:.2f} MB)")
# Out:
# Size: 34062687 bytes (32.48 MB)

# %%
est_4det_size = 2100 * 2100/8.6

File_sizes_Flow = [0.059, 1.2, 1.2]
File_sizes_Original = [8.6, 2100, est_4det_size]
Number_of_Detectors = [2, 3, 4]

# %%
plt.plot(Number_of_Detectors, File_sizes_Flow, marker='o', label='FLOW')
plt.plot(Number_of_Detectors, File_sizes_Original, marker='o', label='Original')
plt.xticks(Number_of_Detectors)
plt.xlabel('Number of Detectors')
plt.ylabel('File Size (MB)')
plt.title('File Size vs Number of Detectors')
plt.yscale('log')
plt.legend()
